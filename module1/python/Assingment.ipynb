# %% [markdown]
# >Write a python program to sum of the first n positive integers

# %%
num = int(input("Enter a positive interger: "))

sum = 0
for i in range(1,num+1):
    sum+=i
print(f"The sum of the first {num} positve intergers is {sum}")
# Out:
# The sum of the first 5 positve intergers is 15

# %% [markdown]
# >Write a Python program to count occurrences of a substring in a string.

# %%
string = str(input("Enter anything in words:"))
substring = str(input("Enter any words you want to count in your text:"))

occurence = string.count(substring)

print(f"{substring} occur {occurence} times in your text")
# Out:
# patel occur 1 times in your text

# %% [markdown]
# 8. Write a Python program to check whether a list contains a sublist. 9. Write a Python program to find the second smallest number in a list. 10.Write a Python program to get unique values from a list. 11.Write a Python program to unzip a list of tuples into individual lists. 12.Write a Python program to convert a list of tuples into a dictionary
# 13.Write a Python program to sort a dictionary (ascending /descending) by value. 14.Write a Python program to find the highest 3 values in a dictionary.

# %% [markdown]
# >Write a Python program to count the occurrences of each word in a givensentence.

# %%
text = str(input("Enter anything you want in string format:")).lower()

words = text.split()
word_count = {}

for word in words:
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1 
for word,count in word_count.items():
    print(f'{word} : {count}')
# Out:
# dharmik : 2

# %% [markdown]
# >Write a Python program to get a single string from two given strings, separatedbya space and swap the first two characters of each string.

# %%
str1 = str(input("Enter one string:"))
str2 = str(input("Enter second string:"))

new_str = str2[:2] + str1[2:]
new_str1 = str1[:2] + str2[2:]

print(f"Swapped strings are: {new_str}  {new_str1}")
# Out:
# Swapped strings are: paarmik  Dhtel

# %% [markdown]
# >Write a Python program to add 'ing' at the end of a given string (length shouldbeat least 3). If the given string already ends with 'ing' then add 'ly' instead If thestring length of the given string is less than 3, leave it unchanged

# %%
string = str(input("Enter any one word:"))
if len(string)<3:
    print(f"{string} is unchanged")
elif string[-3:] != 'ing':
    print(f"{string + 'ing'}")
else:
    print(f"{string.replace(string[-3:],'ly')}")
# Out:
# kly

# %% [markdown]
# >Write a Python program to find the first appearance of the substring 'not' and'poor' from a given string, if 'not' follows the 'poor', replace the whole 'not'...'poor' substring with 'good'. Return the resulting string

# %%
sentence = str(input("Write any sentence:"))    
words = sentence.split()
for i in range(len(words)):
    if words[i] ==  'not' or words[i] == 'poor':
        if words[i] == 'not' and words[i+1] == 'poor':
            words[i] = 'good'
            words[i+1] = ''
    else:
        pass

sentence = " ".join(word for word in words if word != '')
print(sentence)
        
# sentence = input("Write any sentence: ")

# not_pos = sentence.find('not')
# poor_pos = sentence.find('poor')

# if not_pos != -1 and poor_pos != -1 and poor_pos > not_pos:
#     sentence = sentence[:not_pos] + 'good' + sentence[poor_pos + 4:]

# print("Result:", sentence)
# Out:
# dharmik is good boy

# %% [markdown]
# >Program to find Greatest Common Divisor of two numbers. For example, the GCD of 20 and 28 is 4 and the GCD of 98 and 56 is 14.

# %%
def find_gcd(a, b):
    while b != 0:
        a, b = b, a % b
    return a

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print(f"The GCD of {num1} and {num2} is {find_gcd(num1, num2)}")
# Out:
# The GCD of 20 and 28 is 4

# %% [markdown]
# >Write a Python program to check whether a list contains a sublist.

# %%
main_list = [1, 2, 3, 4, 5, 6]
sub_list = [3, 4, 5]

if str(sub_list)[1:-1] in str(main_list)[1:-1]:
    print("Yes, the list contains the sublist.")
else:
    print("No, the list does not contain the sublist.")
# Out:
# Yes, the list contains the sublist.

# %% [markdown]
# >Write a Python program to find the second smallest number in a list

# %%
numbers = [5, 2, 8, 1, 9, 3]

numbers.sort()
print("The second smallest number is:", numbers[1])
# Out:
# The second smallest number is: 2

# %% [markdown]
# >Write a Python program to get unique values from a list.

# %%
numbers = [1,2,2,3,4,4,5,1]

unique_numbers = list(set(numbers))
print("Unique values are:", unique_numbers)
# Out:
# Unique values are: [1, 2, 3, 4, 5]

# %% [markdown]
# >Write a Python program to unzip a list of tuples into individual lists.

# %%
tuple = [(1, 2), (3, 4), (5, 6)]

list1, list2 = map(list, zip(*tuple))
print("List 1:", list1)
print("List 2:", list2)
# Out:
# List 1: [1, 3, 5]
# List 2: [2, 4, 6]

# %% [markdown]
# >Write a Python program to convert a list of tuples into a dictionary

# %%
tuple = [(1, 2), (3, 4), (5, 6)]

dictionary = dict(tuple)

print(dictionary)
# Out:
# {1: 2, 3: 4, 5: 6}

# %% [markdown]
# >Write a Python program to sort a dictionary (ascending /descending) by value

# %%
dic = {"Dharmik" : 22, "Kush" : 20, "Neer" : 18}
sort_values = sorted(dic.items(),key = lambda x : x [1],reverse=True)
print(sort_values)
# Out:
# [('Dharmik', 22), ('Kush', 20), ('Neer', 18)]

# %% [markdown]
# >Write a Python program to find the highest 3 values in a dictionary

# %%
dic = {"Dharmik" : 22, "Kush" : 20, "Neer" : 18, "Hero" : 14, "Kerin" : 25 }
sort_values = sorted(dic.items(),key = lambda x : x [1],reverse=True)
print(sort_values[:3])
# Out:
# [('Kerin', 25), ('Dharmik', 22), ('Kush', 20)]

# %% [markdown]
# >Given a number n, write a python program to make and print the list of Fibonacci
# series up to n. Input : n=7 Hint : first 7 numbers in the series Expected output :
# First few Fibonacci numbers are 0, 1, 1, 2, 3, 5, 8, 13

# %%
num = int(input("Enter any number:"))
n1 = 0 
n2 = 1 
print(n1)
print(n2)
for i in range(1,num):
    n3 = n1 + n2
    print(n3)
    n1 = n2 
    n2 = n3
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %% [markdown]
# >Counting the frequencies in a list using a dictionary in Python. Input : [1, 1, 1, 5, 5, 3, 1, 3, 3, 1,4, 4, 4, 2, 2, 2, 2]
# Expected output : 1 : 5 , 2 : 4 , 3 : 3 , 4 : 3 , 5 : 2

# %%
nums = [1, 1, 1, 5, 5, 3, 1, 3, 3, 1, 4, 4, 4, 2, 2, 2, 2]

freq = {}

for n in nums:
    freq[n] = freq.get(n, 0) + 1  

for key, value in freq.items():
    print(f"{key} : {value}")
# Out:
# 1 : 5
# 5 : 2
# 3 : 3
# 4 : 3
# 2 : 4

# %% [markdown]
# >Write a python program using function to find the sum of odd series andevenseries
# Odd series: 12/ 1! +32/ 3! + 52/ 5!+……n
# Even series: 22/ 2! + 42/ 4! + 62/ 6!+……n

# %%
def freq(n):
    sum_even = 0
    sum_odd = 0
    for i in range(n):
        if i % 2 == 0:
            sum_even += i
        else:
            sum_odd += i
    print(f"sum of even numbers: {sum_even}")
    print(f"sum of odd numbers: {sum_odd}")
num = int(input("Enter Any one number:"))
freq(num)
# Out:
# sum of even numbers: 12
# sum of odd numbers: 16

# %% [markdown]
# >Python Program to Find Factorial of Number Using Recursion

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

num = int(input("Enter a number: "))

if num < 0:
    print("Factorial is not defined for negative numbers.")
else:
    print(f"The factorial of {num} is {factorial(num)}")
# Out:
# The factorial of 5 is 120

# %% [markdown]
# >Write a Python function that takes a list and returns a new list with unique
# elements of the first list.

# %%
def unique_list(lst):
    unique = []
    for item in lst:
        if item not in unique:
            unique.append(item)
    return unique

# Example usage
numbers = [1, 2, 2, 3, 4, 4, 5, 5]
print("Original List:", numbers)
print("Unique List:", unique_list(numbers))
# Out:
# Original List: [1, 2, 2, 3, 4, 4, 5, 5]
# Unique List: [1, 2, 3, 4, 5]

# %% [markdown]
# >Mini project :
# Problem Statement : Password Generator
# Make a program to generate a strong password using the input given by theuser. To generate a password, randomly take some words from the user input andtheninclude numbers, special characters and capital letters to generate the password. Also, keep a check that password length is more than 8 characters. Note: Include Exception handling wherever required. Also, make a ‘User’ classand store the details like user id, name and password of each user as a tuple.

# %%
import random
import string

class User:
    def __init__(self, user_id, name, password):
        self.user_id = user_id
        self.name = name
        self.password = password

    def get_details(self):
        return (self.user_id, self.name, self.password)

def generate_password(text):
    words = text.split()
    if not words:
        raise ValueError("Please enter at least one word!")

    selected = random.choice(words)

    numbers = random.choice(string.digits)
    symbols = random.choice("!@#$%^&*")
    capital = random.choice(selected).upper()

    password = selected + capital + symbols + numbers 

    while len(password) < 8:
        password += random.choice(string.ascii_letters + string.digits)

    return password

try:
    user_id = input("Enter User ID: ")
    name = input("Enter Name: ")
    text = input("Enter some words: ")

    password = generate_password(text)
    user = User(user_id, name, password)

    print("\nUser Details (as Tuple):", user.get_details())
    print("Generated Password:", password)

except Exception as e:
    print("Error:", e)
# Out:
# User Details (as Tuple): ('1', 'dharmik', 'dkpate001P$8')
# Generated Password: dkpate001P$8
